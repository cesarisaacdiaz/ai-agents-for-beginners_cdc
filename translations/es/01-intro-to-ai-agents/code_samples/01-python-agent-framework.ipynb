# %% [markdown]
# # 🐍 Agente de Viajes Inteligente con Microsoft Agent Framework (Python)
#
# ## 📋 Resumen del Escenario
#
# Este notebook demuestra cómo construir un agente inteligente para la planificación de viajes utilizando el Microsoft Agent Framework para Python. El agente aprovecha los Modelos de GitHub para generar automáticamente itinerarios personalizados de excursiones de un día a destinos aleatorios en todo el mundo.
#
# **Características principales:**
# - 🎲 **Selección Inteligente de Destinos**: Función personalizada para elegir destinos aleatorios
# - 🗺️ **Generación de Itinerarios Detallados**: Planificación de viajes impulsada por IA con recomendaciones locales
# - 🔄 **Procesamiento Asíncrono**: Utiliza asyncio para una comunicación eficiente con las API
# - 🛠️ **Integración de Herramientas**: Demuestra capacidades de llamadas a funciones en agentes de IA
#
# ## 🏗️ Implementación Técnica
#
# ### Componentes Principales
# - **Agent Framework**: Implementación en Python del sistema de orquestación de agentes de Microsoft
# - **API de Modelos de GitHub**: Acceso a modelos de lenguaje de última generación a través del servicio de inferencia de GitHub
# - **Compatibilidad con OpenAI**: Utiliza patrones de cliente de OpenAI con el backend de Modelos de GitHub
# - **Gestión de Entorno**: Manejo seguro de credenciales con python-dotenv
#
# ### Flujo de Arquitectura
# ```python
# User Request → ChatAgent → GitHub Models API ↔ get_random_destination()
#                      ↓
#               Travel Itinerary Response
# ```
#
# ### Clases y Métodos Clave
# - `ChatAgent`: Orquestador principal del agente conversacional
# - `OpenAIChatClient`: Wrapper del cliente API de Modelos de GitHub
# - `get_random_destination()`: Función personalizada para la selección de destinos
# - Variables de entorno: Gestión segura de configuración de API
#
# ## ⚙️ Requisitos Previos y Configuración
#
# **Dependencias Necesarias:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Configuración del Entorno (archivo .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Acceso a Modelos de GitHub:**
# 1. Regístrate para acceder a los Modelos de GitHub
# 2. Genera un token de acceso personal
# 3. Configura las variables de entorno como se muestra arriba
#
# ## 🚀 Instrucciones de Uso
#
# Ejecuta las celdas a continuación en secuencia para:
# 1. Importar las bibliotecas necesarias y cargar las variables de entorno
# 2. Definir la herramienta generadora de destinos aleatorios
# 3. Crear y configurar el agente de IA
# 4. Ejecutar solicitudes de planificación de viajes y ver los resultados
#
# ¡Construyamos un asistente inteligente para la planificación de viajes! 🌟

# %%
! pip install agent-framework-core -U
# Out:
# Requirement already satisfied: agent-framework-core in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (1.0.0b260130)
# Requirement already satisfied: typing-extensions in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from agent-framework-core) (2.11.10)
# Requirement already satisfied: pydantic-settings<3,>=2 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from agent-framework-core) (2.12.0)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from agent-framework-core) (1.109.1)
# Requirement already satisfied: azure-identity<2,>=1 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from agent-framework-core) (1.25.1)
# Requirement already satisfied: mcp<2,>=1.24.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (1.26.0)
# Requirement already satisfied: packaging>=24.1 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from agent-framework-core) (26.0)
# Requirement already satisfied: azure-core>=1.31.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.38.0)
# Requirement already satisfied: cryptography>=2.5 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.4)
# Requirement already satisfied: msal>=1.30.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: anyio>=4.5 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.26.0)
# Requirement already satisfied: pyjwt>=2.10.1 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.0.22)
# Requirement already satisfied: pywin32>=310 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.50.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.40.0)
# Requirement already satisfied: websockets>=15.0.1 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (15.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from pydantic<3,>=2->agent-framework-core) (2.33.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.2.1)
# Requirement already satisfied: idna>=2.8 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from anyio>=4.5->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.11)
# Requirement already satisfied: requests>=2.21.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (3.0)
# Requirement already satisfied: certifi in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.36.2)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.6.3)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from openai>=1.99.0->agent-framework-core) (0.12.0)
# Requirement already satisfied: sniffio in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from openai>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from openai>=1.99.0->agent-framework-core) (4.67.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from opentelemetry-api>=1.39.0->agent-framework-core) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core) (0.60b1)
# Requirement already satisfied: colorama in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from tqdm>4->openai>=1.99.0->agent-framework-core) (0.4.6)
# Requirement already satisfied: click>=7.0 in C:\Github\Local\ai-agents-for-beginners_cdc\.venv\Lib\site-packages (from uvicorn>=0.31.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (8.3.1)

# %%
# 📦 Import Required Libraries
# Standard library imports for system operations and random number generation
import os
from random import randint

# Third-party library for loading environment variables from .env file
from dotenv import load_dotenv

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatAgent: The main agent class for conversational AI
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs (including GitHub Models)
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# This loads configuration from a .env file in the project root
# Required variables: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎲 Tool Function: Random Destination Generator
# This function will be available to the agent as a tool
# The agent can call this function to get random vacation destinations
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    Returns:
        str: A randomly selected destination from our predefined list
    """
    # List of popular vacation destinations around the world
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a random destination from the list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client for GitHub Models
# This client connects to GitHub Models API (OpenAI-compatible endpoint)
# Environment variables required:
# - GITHUB_ENDPOINT: API endpoint URL (usually https://models.inference.ai.azure.com)
# - GITHUB_TOKEN: Your GitHub personal access token
# - GITHUB_MODEL_ID: Model to use (e.g., gpt-4o-mini, gpt-4o)
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),
    api_key=os.environ.get("GITHUB_TOKEN"), 
    model_id=os.environ.get("GITHUB_MODEL_ID")
)

# %%
# 🤖 Create the Travel Planning Agent
# This creates a conversational AI agent with specific capabilities:
# - chat_client: The AI model client for generating responses
# - instructions: System prompt that defines the agent's personality and role
# - tools: List of functions the agent can call to perform actions
agent = ChatAgent(
    chat_client=openai_chat_client,
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",
    tools=[get_random_destination]  # Our random destination tool function
)

# %%
# 🚀 Run the Agent
# Send a message to the agent and get a response
# The agent will use its tools (get_random_destination) if needed
response = await agent.run("Plan me a day trip")

# %%
# 📋 View Raw Response Object
# This shows the complete response structure including metadata
# Useful for debugging and understanding the response format
response

# %%
# 📖 Extract and Display the Travel Plan
# Get the last message from the conversation (agent's response)s
last_message = response.messages[-1]
# Extract the text content from the message
text_content = last_message.contents[0].text
# Display the formatted travel plan
print("🏖️ Travel plan:")
print(text_content)
# Out:
# 🏖️ Travel plan:
# Let's plan a fantastic day trip to Cape Town, South Africa!
#
# **Morning:**
# - Kick off your day with a refreshing hike up **Lion’s Head**. The views from the summit are stunning, giving you a panoramic look at Cape Town, Table Mountain, and the sparkling Atlantic Ocean.
# - After your hike, grab breakfast at **Kloof Street House**, known for its charming ambiance and delicious cuisine.
#
# **Midday:**
# - Explore **V&A Waterfront**, the bustling harbor area dotted with shops, art galleries, and restaurants. Make time to visit the **Two Oceans Aquarium** to learn about marine life.
# - For lunch, try local favorites like a Cape Malay curry or seafood at a waterfront restaurant such as **Baia**.
#
# **Afternoon:**
# - Head to **Table Mountain**, one of the New7Wonders of Nature. Choose between a cable car ride up or hike to the top for spectacular views. Spend some time enjoying the unique flora and fauna at the summit.
#
# **Evening:**
# - Wind down with a picturesque drive to **Chapman’s Peak**, renowned for its scenic views with towering cliffs on one side and ocean waves on the other.
# - End the day at **Camps Bay Beach**, where you can relax with your feet in the sand and enjoy a sundowner at one of the beachside bars or restaurants.
#
# Let me know if you'd like more details on any part of the trip!

# %% [markdown]
# ---
#
# **Descargo de responsabilidad**:
# Este documento ha sido traducido utilizando el servicio de traducción automática [Co-op Translator](https://github.com/Azure/co-op-translator). Aunque nos esforzamos por garantizar la precisión, tenga en cuenta que las traducciones automatizadas pueden contener errores o imprecisiones. El documento original en su idioma nativo debe considerarse como la fuente autorizada. Para información crítica, se recomienda una traducción profesional realizada por humanos. No nos hacemos responsables de malentendidos o interpretaciones erróneas que puedan surgir del uso de esta traducción.
